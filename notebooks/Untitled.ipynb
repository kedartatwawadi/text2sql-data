# %%
# %load_ext sql
# %sql sqlite:///../data/atis-sqlite.db
# Out:
# 'Connected: @../data/atis-sqlite.db'

# %%
fdb=("../data/atis-sqlite.db")
db = records.Database('sqlite:///{}'.format(fdb))

# %%
# %sql PRAGMA table_info(flight);
# Out:
#  * sqlite:///../data/atis-sqlite.db
# Done.
# [(0, 'flight_id', 'integer', 1, "'0'", 1),
#  (1, 'flight_days', 'text', 0, None, 0),
#  (2, 'from_airport', 'varchar(3)', 0, 'NULL', 0),
#  (3, 'to_airport', 'varchar(3)', 0, 'NULL', 0),
#  (4, 'departure_time', 'integer', 0, 'NULL', 0),
#  (5, 'arrival_time', 'integer', 0, 'NULL', 0),
#  (6, 'airline_flight', 'text', 0, None, 0),
#  (7, 'airline_code', 'varchar(3)', 0, 'NULL', 0),
#  (8, 'flight_number', 'integer', 0, 'NULL', 0),
#  (9, 'aircraft_code_sequence', 'text', 0, None, 0),
#  (10, 'meal_code', 'text', 0, None, 0),
#  (11, 'stops', 'integer', 0, 'NULL', 0),
#  (12, 'connections', 'integer', 0, 'NULL', 0),
#  (13, 'dual_carrier', 'text', 0, None, 0),
#  (14, 'time_elapsed', 'integer', 0, 'NULL', 0)]

# %%
# %sql SELECT DISTINCT flight_id FROM flight WHERE to_airport="BOS";
# Out:
#  * sqlite:///../data/atis-sqlite.db
# Done.
# [(100598, 'BOS'),
#  (100599, 'BOS'),
#  (100600, 'BOS'),
#  (100601, 'BOS'),
#  (100602, 'BOS'),
#  (100603, 'BOS'),
#  (100604, 'BOS'),
#  (100605, 'BOS'),
#  (100606, 'BOS'),
#  (100607, 'BOS'),
#  (100608, 'BOS'),
#  (100609, 'BOS'),
#  (100610, 'BOS'),
#  (100611, 'BOS'),
#  (100612, 'BOS'),
#  (100613, 'BOS'),
#  (100614, 'BOS'),
#  (100615, 'BOS'),
#  (100616, 'BOS'),
#  (100617, 'BOS'),
#  (100618, 'BOS'),
#  (100619, 'BOS'),
#  (100620, 'BOS'),
#  (100621, 'BOS'),
#  (100622, 'BOS'),
#  (100623, 'BOS'),
#  (100624, 'BOS'),
#  (100625, 'BOS'),
#  (100626, 'BOS'),
#  (100627, 'BOS'),
#  (100628, 'BOS'),
#  (100629, 'BOS'),
#  (100630, 'BOS'),
#  (100631, 'BOS'),
#  (100632, 'BOS'),
#  (100633, 'BOS'),
#  (100634, 'BOS'),
#  (100635, 'BOS'),
#  (100636, 'BOS'),
#  (100637, 'BOS'),
#  (100638, 'BOS'),
#  (100639, 'BOS'),
#  (100640, 'BOS'),
#  (100641, 'BOS'),
#  (100642, 'BOS'),
#  (100643, 'BOS'),
#  (100644, 'BOS'),
# ...
